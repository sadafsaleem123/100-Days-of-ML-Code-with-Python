# %% [markdown]
# # **Data Analysis in Python**

# %% [markdown]
# ### Resource used
# https://youtube.com/playlist?list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS

# %%
import pandas as pd

# %%
df = pd.read_csv('/var/survey_results_public.csv')
schema_df = pd.read_csv('/survey_results_schema.csv')

# %%
df.head(5)
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df.tail(5)
# Out:
#       Respondent                                       Professional  \
# 2960        2961                                            Student
# 2961        2962                             Professional developer
# 2962        2963                             Professional developer
# 2963        2964  Professional non-developer who sometimes write...
# 2964        2965                             Professional developer
#
#                    ProgramHobby        Country      University  \
# 2960  Yes, I program as a hobby     Bangladesh  Yes, full-time
# 2961                  Yes, both        Georgia  Yes, part-time
# 2962  Yes, I program as a hobby  United States              No
# 2963  Yes, I program as a hobby  United States              No
# 2964                  Yes, both  United States              No
#
#                             EmploymentStatus    FormalEducation  \
# 2960  Not employed, and not looking for work   Secondary school
# ...

# %%
df.shape
# Out:
# (2965, 154)

# %%
schema_df.shape
# Out:
# (154, 2)

# %%
df.columns
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=154)

# %%
df['Respondent']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2960    2961
# 2961    2962
# 2962    2963
# 2963    2964
# 2964    2965
# Name: Respondent, Length: 2965, dtype: int64

# %%
df.loc[0:2, 'Respondent':'MajorUndergrad']
# Out:
#    Respondent            Professional ProgramHobby         Country  \
# 0           1                 Student    Yes, both   United States
# 1           2                 Student    Yes, both  United Kingdom
# 2           3  Professional developer    Yes, both  United Kingdom
#
#        University                        EmploymentStatus  \
# 0              No  Not employed, and not looking for work
# 1  Yes, full-time                      Employed part-time
# 2              No                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
#
#                              MajorUndergrad
# 0                                       NaN
# 1  Computer science or software engineering
# 2  Computer science or software engineering

# %% [markdown]
# # **Pandas DataFrame and Series**
