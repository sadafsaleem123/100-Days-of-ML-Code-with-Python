# %% [markdown]
# # **Andrew Ng Linear Regression**
#
# Link: https://www.youtube.com/playlist?list=PLJs7lEb1U5pYnrI0Wn4mzPmppVqwERL_4

# %% [markdown]
# As an example of Supervised Learning Algorithm, we consider taking the size of the housing data and predicting it's prices.
#
# ### **Notatations:**
#
# m = Number of training examples
#
# x's = input variable / features
#
# y's = otput variable/ target variable
#
# (x, y) - training example

# %% [markdown]
# ![76.PNG](data:image/png;base64,...)
